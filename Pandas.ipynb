# %%
import pandas as pd
review=pd.read_csv("score.csv") #csv file
review.head()  #
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR                    INSTURL  \
# 0     AL              www.aamu.edu/
# 1     AL                www.uab.edu
# 2     AL  www.amridgeuniversity.edu
# 3     AL                www.uah.edu
# 4     AL              www.alasu.edu
#
#                                               NPCURL  HCM2  PREDDEG  \
# 0      www2.aamu.edu/scripts/netpricecalc/npcalc.htm     0        3
# 1           uab.studentaidcalculator.com/survey.aspx     0        3
# 2                   www2.amridgeuniversity.edu:9091/     0        3
# ...

# %%
import pandas as pd
review=pd.read_csv("score.csv")
review.shape
# Out:
# (7593, 123)

# %%
import pandas as pd
review=pd.read_csv("score.csv")
review.iloc[0:10,:]
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM  \
# 0  100654   100200    1002             Alabama A & M University
# 1  100663   105200    1052  University of Alabama at Birmingham
# 2  100690  2503400   25034                   Amridge University
# 3  100706   105500    1055  University of Alabama in Huntsville
# 4  100724   100500    1005             Alabama State University
# 5  100751   105100    1051            The University of Alabama
# 6  100760   100700    1007    Central Alabama Community College
# 7  100812   100800    1008              Athens State University
# 8  100830   831000    8310      Auburn University at Montgomery
# 9  100858   100900    1009                    Auburn University
#
#              CITY STABBR                    INSTURL  \
# 0          Normal     AL              www.aamu.edu/
# 1      Birmingham     AL                www.uab.edu
# 2      Montgomery     AL  www.amridgeuniversity.edu
# ...

# %%
review.iloc[:,1:3]
# Out:
#          OPEID  OPEID6
# 0       100200    1002
# 1       105200    1052
# 2      2503400   25034
# 3       105500    1055
# 4       100500    1005
# 5       105100    1051
# 6       100700    1007
# 7       100800    1008
# 8       831000    8310
# 9       100900    1009
# 10      101200    1012
# 11     1218200   12182
# 12     1055400   10554
# 13     1303906   13039
# 14      101500    1015
# 15      106000    1060
# 16      100300    1003
# 17      101700    1017
# 18     4187200   41872
# 19      101800    1018
# 20      787100    7871
# 21      569900    5699
# 22      962107    9621
# 23      101900    1019
# 24     2199700   21997
# 25      526000    5260
# 26      102000    1020
# 27      102100    1021
# 28      102200    1022
# 29      101300    1013
# ...        ...     ...
# 7563    145946    1459
# 7564    145952    1459
# 7565    145959    1459
# 7566    145965    1459
# 7567    145971    1459
# 7568    145972    1459
# 7569    145996    1459
# 7570    145945    1459
# ...

# %%
review["CITY"]
# Out:
# 0                 Normal
# 1             Birmingham
# 2             Montgomery
# 3             Huntsville
# 4             Montgomery
# 5             Tuscaloosa
# 6         Alexander City
# 7                 Athens
# 8             Montgomery
# 9                 Auburn
# 10            Birmingham
# 11           Phenix City
# 12                 Selma
# 13            Montgomery
# 14            Enterprise
# 15           Bay Minette
# 16            Montgomery
# 17               Gadsden
# 18           Albertville
# 19                Dothan
# 20            Hanceville
# 21                 Selma
# 22            Birmingham
# 23            Montgomery
# 24              Florence
# 25            Huntsville
# 26          Jacksonville
# 27               Brewton
# 28            Birmingham
# 29                Tanner
#               ...
# 7563              Morrow
# 7564             Roswell
# 7565        Douglasville
# 7566            Lithonia
# 7567            Savannah
# 7568             Augusta
# ...

# %%
review[["CITY","OPEID"]]
# Out:
#                   CITY     OPEID
# 0               Normal    100200
# 1           Birmingham    105200
# 2           Montgomery   2503400
# 3           Huntsville    105500
# 4           Montgomery    100500
# 5           Tuscaloosa    105100
# 6       Alexander City    100700
# 7               Athens    100800
# 8           Montgomery    831000
# 9               Auburn    100900
# 10          Birmingham    101200
# 11         Phenix City   1218200
# 12               Selma   1055400
# 13          Montgomery   1303906
# 14          Enterprise    101500
# 15         Bay Minette    106000
# 16          Montgomery    100300
# 17             Gadsden    101700
# 18         Albertville   4187200
# 19              Dothan    101800
# 20          Hanceville    787100
# 21               Selma    569900
# 22          Birmingham    962107
# 23          Montgomery    101900
# 24            Florence   2199700
# 25          Huntsville    526000
# 26        Jacksonville    102000
# ...

# %%
import pandas as pd
review=pd.read_csv("score.csv")
review.count()
# Out:
# UNITID                    7593
# OPEID                     7593
# OPEID6                    7593
# INSTNM                    7593
# CITY                      7593
# STABBR                    7593
# INSTURL                   7573
# NPCURL                    7075
# HCM2                      7593
# PREDDEG                   7593
# HIGHDEG                   7593
# CONTROL                   7593
# LOCALE                    7147
# HBCU                      7147
# PBI                       7147
# ANNHI                     7147
# TRIBAL                    7147
# AANAPII                   7147
# HSI                       7147
# NANTI                     7147
# MENONLY                   7147
# WOMENONLY                 7147
# RELAFFIL                   909
# SATVR25                   1193
# SATVR75                   1193
# SATMT25                   1202
# SATMT75                   1202
# SATWR25                    733
# SATWR75                    733
# SATVRMID                  1193
# ...

# %%
review.corr()
# Out:
#                 UNITID     OPEID    OPEID6      HCM2   PREDDEG   HIGHDEG  \
# UNITID        1.000000 -0.003816  0.001936 -0.020568 -0.389325 -0.371586
# OPEID        -0.003816  1.000000  0.405211  0.026050 -0.086548 -0.094026
# OPEID6        0.001936  0.405211  1.000000  0.083623 -0.378512 -0.422724
# HCM2         -0.020568  0.026050  0.083623  1.000000 -0.038111 -0.045841
# PREDDEG      -0.389325 -0.086548 -0.378512 -0.038111  1.000000  0.911204
# HIGHDEG      -0.371586 -0.094026 -0.422724 -0.045841  0.911204  1.000000
# CONTROL       0.109634  0.266735  0.483255  0.056454 -0.334517 -0.331159
# LOCALE       -0.135061 -0.079378 -0.131285 -0.027185 -0.009032 -0.031668
# HBCU         -0.097842 -0.051925 -0.108620  0.011242  0.109639  0.107352
# PBI          -0.056962 -0.027138 -0.045178 -0.000838  0.008613  0.036105
# ANNHI        -0.035113 -0.013268 -0.021497 -0.006371  0.030821  0.029913
# TRIBAL       -0.003791  0.013405  0.047653  0.033424 -0.000816  0.007329
# ...

# %%
review.max()
# Out:
# UNITID                                            48621101
# OPEID                                             82098842
# OPEID6                                               42542
# INSTNM          eClips School of Cosmetology and Barbering
# CITY                                          white plains
# STABBR                                                  WY
# HCM2                                                     1
# PREDDEG                                                  4
# HIGHDEG                                                  4
# CONTROL                                                  3
# LOCALE                                                  43
# HBCU                                                     1
# PBI                                                      1
# ANNHI                                                    1
# TRIBAL                                                   1
# AANAPII                                                  1
# ...

# %%
review.min()
# Out:
# UNITID                              100654
# OPEID                               100200
# OPEID6                                1002
# INSTNM          A & W Healthcare Educators
# CITY                               ARTESIA
# STABBR                                  AK
# HCM2                                     0
# PREDDEG                                  0
# HIGHDEG                                  0
# CONTROL                                  1
# LOCALE                                  -3
# HBCU                                     0
# PBI                                      0
# ANNHI                                    0
# TRIBAL                                   0
# AANAPII                                  0
# HSI                                      0
# NANTI                                    0
# MENONLY                                  0
# WOMENONLY                                0
# RELAFFIL                                22
# SATVR25                                292
# ...

# %%
review["OPEID"]/2
# Out:
# 0         50100.0
# 1         52600.0
# 2       1251700.0
# 3         52750.0
# 4         50250.0
# 5         52550.0
# 6         50350.0
# 7         50400.0
# 8        415500.0
# 9         50450.0
# 10        50600.0
# 11       609100.0
# 12       527700.0
# 13       651953.0
# 14        50750.0
# 15        53000.0
# 16        50150.0
# 17        50850.0
# 18      2093600.0
# 19        50900.0
# 20       393550.0
# 21       284950.0
# 22       481053.5
# 23        50950.0
# 24      1099850.0
# 25       263000.0
# 26        51000.0
# 27        51050.0
# 28        51100.0
# 29        50650.0
#           ...
# 7563      72973.0
# 7564      72976.0
# 7565      72979.5
# 7566      72982.5
# 7567      72985.5
# 7568      72986.0
# 7569      72998.0
# 7570      72972.5
# 7571      72977.0
# 7572      72995.0
# 7573      72996.0
# 7574      72997.0
# 7575      72997.5
# 7576    5072950.0
# 7577    5072950.5
# 7578    5072954.0
# 7579    5072954.5
# 7580    2084850.5
# 7581    2104300.5
# ...

# %%
review.loc[1]
# Out:
# UNITID                                                      100663
# OPEID                                                       105200
# OPEID6                                                        1052
# INSTNM                         University of Alabama at Birmingham
# CITY                                                    Birmingham
# STABBR                                                          AL
# INSTURL                                                www.uab.edu
# NPCURL                    uab.studentaidcalculator.com/survey.aspx
# HCM2                                                             0
# PREDDEG                                                          3
# HIGHDEG                                                          4
# CONTROL                                                          1
# LOCALE                                                          12
# HBCU                                                             0
# ...

# %%
review.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR                    INSTURL  \
# 0     AL              www.aamu.edu/
# 1     AL                www.uab.edu
# 2     AL  www.amridgeuniversity.edu
# 3     AL                www.uah.edu
# 4     AL              www.alasu.edu
#
#                                               NPCURL  HCM2  PREDDEG  \
# 0      www2.aamu.edu/scripts/netpricecalc/npcalc.htm     0        3
# 1           uab.studentaidcalculator.com/survey.aspx     0        3
# 2                   www2.amridgeuniversity.edu:9091/     0        3
# ...

# %%
review.std()
# Out:
# UNITID          6.771661e+06
# OPEID           3.516382e+06
# OPEID6          1.408887e+04
# HCM2            9.758556e-02
# PREDDEG         1.031903e+00
# HIGHDEG         1.318152e+00
# CONTROL         8.359409e-01
# LOCALE          9.415183e+00
# HBCU            1.186171e-01
# PBI             1.203232e-01
# ANNHI           6.247340e-02
# TRIBAL          6.881331e-02
# AANAPII         1.284938e-01
# HSI             2.238282e-01
# NANTI           6.135197e-02
# MENONLY         9.493825e-02
# WOMENONLY       7.367372e-02
# RELAFFIL        2.101654e+01
# SATVR25         7.036988e+01
# SATVR75         7.150669e+01
# SATMT25         7.469998e+01
# SATMT75         7.507693e+01
# SATWR25         8.203630e+01
# SATWR75         8.069504e+01
# SATVRMID        6.959606e+01
# SATMTMID        7.354111e+01
# SATWRMID        8.016365e+01
# ACTCM25         3.602933e+00
# ACTCM75         3.497463e+00
# ACTEN25         4.111679e+00
#                     ...
# PCIP52          1.445066e-01
# ...

# %%
review.dtypes
# Out:
# UNITID                      int64
# OPEID                       int64
# OPEID6                      int64
# INSTNM                     object
# CITY                       object
# STABBR                     object
# INSTURL                    object
# NPCURL                     object
# HCM2                        int64
# PREDDEG                     int64
# HIGHDEG                     int64
# CONTROL                     int64
# LOCALE                    float64
# HBCU                      float64
# PBI                       float64
# ANNHI                     float64
# TRIBAL                    float64
# AANAPII                   float64
# HSI                       float64
# NANTI                     float64
# MENONLY                   float64
# WOMENONLY                 float64
# RELAFFIL                  float64
# SATVR25                   float64
# SATVR75                   float64
# SATMT25                   float64
# SATMT75                   float64
# ...

# %%
review.head(20)
# Out:
#     UNITID    OPEID  OPEID6                                           INSTNM  \
# 0   100654   100200    1002                         Alabama A & M University
# 1   100663   105200    1052              University of Alabama at Birmingham
# 2   100690  2503400   25034                               Amridge University
# 3   100706   105500    1055              University of Alabama in Huntsville
# 4   100724   100500    1005                         Alabama State University
# 5   100751   105100    1051                        The University of Alabama
# 6   100760   100700    1007                Central Alabama Community College
# 7   100812   100800    1008                          Athens State University
# 8   100830   831000    8310                  Auburn University at Montgomery
# 9   100858   100900    1009                                Auburn University
# 10  100937   101200    1012                      Birmingham Southern College
# ...

# %%
import pandas as pd
review=pd.read_table("a.txt")
review.head()
# Out:
#        vishal
# 0  maheshwari
# 1  python ml
# 2     android
# 3        java
# 4      studio

# %%
review.dtypes
# Out:
# vishal    object
# dtype: object

# %%
review.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 1 columns):
# vishal    6 non-null object
# dtypes: object(1)
# memory usage: 128.0+ bytes

# %%
review.sort_values("vishal")
# Out:
#        vishal
# 2     android
# 3        java
# 5         jdk
# 0  maheshwari
# 1  python ml
# 4      studio
